# %% [markdown]
# <a href="https://colab.research.google.com/github/shailendrat09/gitpractice/blob/main/IDEMI_Day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <span style = 'color:blue'> visualization tour</span>.

# %% [markdown]
# <i>basic libraries used for visualization are

# %% [markdown]
# ###  <span style = 'color:blue'> 1.matplotlib.pyplot as plt usually</span>
# #####  Matplotlib is a visualization library in python for 2D plots of arrays, it is written in python and makes use of numpy library.Matplotlib was introduced by John Hunter in 2002.
# ### <span style = 'color:blue'> 2.seaborn as sns generally </span>
# ##### Seaborn is a dataset-oriented library for making statistical representations in python. It is devoloped atop matplotlib and to create diffrent visualization.

# %% [markdown]
# #### matplotlib vs seaborn

# %% [markdown]
# ![main-qimg-2c66964b9c14d5371fbf42b97d0f5f3e.png](attachment:main-qimg-2c66964b9c14d5371fbf42b97d0f5f3e.png)

# %%
# Loading the data set
iris = pd.read_csv("Iris.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d3e7066551f6> in <cell line: 2>()
#       1 # Loading the data set
# ----> 2 iris = pd.read_csv("Iris.csv")
#
# NameError: name 'pd' is not defined

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# Let's see how many examples we have of each species
iris["Species"].value_counts()
# Out:
# Iris-virginica     50
# Iris-versicolor    50
# Iris-setosa        50
# Name: Species, dtype: int64

# %% [markdown]
# ##  <span style = 'color:blue'> 1.matplotlib.pyplot as plt usually</span>
#
# ![1024px-Created_with_Matplotlib-logo.svg-2.png](attachment:1024px-Created_with_Matplotlib-logo.svg-2.png)

# %% [markdown]
# 1. To make necessary statistical inferences, it becomes necessary to visualize your data and Matplotlib is one such solution for the Python users. It is a very powerful plotting library useful for those working with Python
# 2. Pyplot is a Matplotlib module that provides simple functions for adding plot elements, such as lines, images, text, etc. to the axes in the current figure.
# 3. matplotlib.pyplot is a collection of command style functions that make matplotlib work like MATLAB.
# 4. it is visualization library in python for plots of arrays, it is written in python and makes use of numpy library.

# %% [markdown]
# ##### 1.1 simple plotting

# %% [markdown]
# ##### line plot
# Here are the basic examples of generating a simple graph

# %%
a= [75, 70, 65, 80, 90, 82, 61, 56,76,89,99]

plt.plot(a)
plt.show()

# %%
a = [50, 20, 70, 40, 40, 80]  # marks of studebt a
b = [12,3,56,78,98,76]
plt.plot(a,b)
plt.title('This is my sample plot for the sample title ') # tittle graph needs
plt.ylabel('This is axis - 1') # labelling y axis
plt.xlabel('This is axis - 2')  # labelling x axis
plt.show() #this function is used to display the pictures

# %% [markdown]
# from the above plot we can clearly see that the student 'a' has got lesser marks than student 'b'

# %%
Year = [1920,1930,1940,1950,1960,1970,1980,1990,2000,2010, 2020]
Unemployment_Rate = [9.8,12,8,7.2,6.9,7,6.5,6.2,5.5,6.3,7.0]

plt.plot(Year, Unemployment_Rate)
plt.title('Unemployment Rate Vs Year,*Updated on 11-04-2023*')
plt.xlabel('Year on decade level')
plt.ylabel('Unemployment Rate on scale of 10')
plt.show()

# %% [markdown]
# from the above graph its clearly visible that the unemployment rate is decreasing as time is passing and can clearly see it in visual format in the above plot

# %% [markdown]
# ##### 1.2 Bar plots

# %% [markdown]
# 1. Bar graph is a graphical representation of data in which we can highlight the category with particular shapes like a rectangle.
# 2. The length and heights of the bar chart represent the data distributed in the dataset. In a bar chart, we have one axis representing a particular category of a column in the dataset and another axis representing the values associated with it.
# 3. Bar charts can be plotted vertically or horizontally. A vertical bar chart is often called a column chart. When we arrange bar charts in a high to low-value counts manner, we called them Pareto charts.

# %%
Batch_1 = ["pranali","amit","sahil","Shyam"]
attendance = [92,93,99,85]
plt.barh(Batch_1,attendance,color='yellow')
plt.show()

# %%
students = ['rohith','Raghav','Shikhar','manoj']  # students who appeared for math exam
marks = [51,87,45,67]  # marks individual scored in exam
plt.bar(students,marks)  # colour needed to fill bars
plt.title(' comparing students marks in bar plot')
plt.xlabel('students marks in maths')  # labelling the x axis
plt.ylabel('marks')  #labelling y axis
plt.show() #used to show plots

# %%
#plotting the same bar graph in horizontal way
#we can even add colours to bars, after inputs include color = (desired colour)
students = ['rohith','Raghav','Shikhar','manoj','Haseena', 'Aamir', 'Shraddha','Anuj','rambi','Jack']  # students who appeared for math exam
marks = [51,87,45,67,78,77,91,81,56,86]  # marks individual scored in exam
plt.barh(students,marks,color = 'cyan')  # colour needed to fill bars
plt.title(' comparing students marks in bar plot')
plt.xlabel('students marks in maths')  # labelling the x axis
plt.ylabel('marks')  #labelling y axis
plt.show() #used to show plots

# %% [markdown]
# from above plot we can clearly makout the diffrence marks scored by the diffrent student who all are appeared in exam
#  - shikar is the one who scored least in exam
#  - raghav is the one who scored highest in exam, manoj and mohith have scored somewhat similar marks

# %% [markdown]
# ##### 1.3 scatter plot helps us understand diffrent insights from the data.

# %% [markdown]
# 1. Different levels of relation between the data points are useful to understand the relationship within the data.
#
# 2. The data points lying outside the given set of data can be easily identified to find the outliers.
#
# 3. Grouping of data points in a scatter plot can be identified as different clusters within the data.

# %%
a = [1,45,3,4,5,6,7,8,9,10]
b = [10,5,8,7,6,5,4,3,2,1]
c = [11,22,33,44,55,66,77,88,99,100]
plt.plot(a,b,'go',alpha = 0.2)
plt.show()

# %%
# simple scatter plot
plt.plot([1,2,3,4],[1,7,8,9],'go')#inputs for plotting
plt.title('simple scatter plot')#giving tittle
plt.xlabel('x-axis')#labelling x axis
plt.ylabel('y-axis')#labelling y axis
plt.show()

# %%
# simple scatter plot
plt.plot([60,71,65,81,90],[100,100,100,100,100],'go')#inputs for plotting
plt.title('Test Plot')#giving tittle
plt.xlabel('x-axis')#labelling x axis
plt.ylabel('y-axis')#labelling y axis
plt.show()

# %% [markdown]
# from the above plot we can clearly see that scattering of the input data

# %%
df
# Out:
#                         Name  Gender  Age         Rating Date Joined  \
# 0    Parasuramudu Jamakayala    Male   20        Average  2020-10-18
# 1      Yedukondalu Panditula    Male   32  Above average  2021-04-07
# 2      Devsena Veluvalapalli  Female   31        Average  2022-04-12
# 3              Gopal Venkata    Male   32        Average  2021-05-23
# 4       Vasavi Veeravasarapu  Female   37           Poor  2020-09-11
# ..                       ...     ...  ...            ...         ...
# 178             Elia Cockton  Female   33        Average  2021-04-26
# 179             Gigi Bohling    Male   33        Average  2021-07-08
# 180          Ebonee Roxburgh    Male   30        Average  2022-05-20
# 181            Shayne Stegel    Male   42           Poor  2022-06-19
# 182               Zach Polon    Male   26        Average  2021-08-03
#
#       Department  Salary Country
# 0        Website  112650     IND
# 1        Website   43840     IND
# 2    Procurement  103550     IND
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Gender', 'Age', 'Rating', 'Date Joined', 'Department',
#        'Salary', 'Country'],
#       dtype='object')

# %%
plt.plot(df['Age'],df['Salary'],'go',alpha=0.2)
plt.show()

# %%
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],alpha=0.5)
plt.title('comparing sepal length and petal length of iris family')
plt.xlabel('sepal length in cm')
plt.ylabel('petal length in cm')
#Show the plot
plt.show()

#using scatterplot to find the relation between the petal length and sepal length
#alpha allows to adjust the transperacy of the graph

# %% [markdown]
# from the above scatter plot it is clearly understanding that one particular iris flower dimension is not matching with another two iris flowers but the remaining two iris flowers dimensions are overlapping

# %%
#scatter plot for sepal length and sepal width insights
fig = iris[iris.Species=='Iris-setosa'].plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm',color='orange', label='Setosa')
iris[iris.Species=='Iris-versicolor'].plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm',color='blue', label='versicolor',ax=fig)
iris[iris.Species=='Iris-virginica'].plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm',color='green', label='virginica', ax=fig)
fig.set_xlabel("Sepal Length")
fig.set_ylabel("Sepal Width")
fig.set_title("Sepal Length VS Width ")
fig=plt.gcf()
fig.set_size_inches(10,4)
plt.show()

# %% [markdown]
# - from above plot we can clearly make out the diffrence between the sepal width and sepal length by using diffrent colours for     diffrent flowers
# - sepal width of setosa is more but the sepal length of verginica is more and versicular partially

# %% [markdown]
# ##### 1.4 histogram

# %% [markdown]
# 1. A histogram is basically used to represent data provided in a form of some groups.
# 2. A histogram is accurate representation of the distribution of numerical data. It is an estimate of the probability distribution of a continuous variable.

# %%
df.columns
# Out:
# Index(['Name', 'Gender', 'Age', 'Rating', 'Date Joined', 'Department',
#        'Salary', 'Country'],
#       dtype='object')

# %%
plt.hist(df['Salary'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#lets draw a simple histogram with realtime data
#
population_age = [21,53,60,49,25,27,30,42,40,1,2,102,95,8,15,105,70,65,55,70,75,60,52,44,43,42,45]
bins = [0,10,20,30,40,50,60,70,90,100,120]
plt.hist(population_age, bins) # bin represents the range of values that are divided into series of intervals. Bins are generally created of the same size
plt.xlabel('age groups')
plt.ylabel('frequency')
plt.title('Histogram')
plt.show()

# %% [markdown]
# - we have plotted histogram for the data of the different age group of the people with respect to the bin.
# - we can observe from the plat that frequency of the people between age 40-50 is greater than any other range

# %% [markdown]
# ##### 1.5 pie chart

# %% [markdown]
# - A Pie Chart is a circular statistical plot that can display only one series of data.
# - The area of the chart is the total percentage of the given data.
# - Pie chart slices will be ordered and plotted counter-clockwise:

# %%
# plotting basic pie chart

y = np.array([99,99,76,17,99,35 ])#no of students in class
mylabels = ["Pranali","Amit","Sahil","Aamir","Haseena","Nazerin"]# area wise allocation

plt.pie(y, labels = mylabels)
plt.show()

# %%
y = np.array([99,99,76,17,99,35 ])#no of students in class
mylabels = ["Pranali","Amit","Sahil","Aamir","Haseena","Nazerin"]# area wise allocation

sample_1 = [0.2,0,0,0,0,0.32]

plt.pie(y, labels = mylabels,explode = sample_1)
plt.show()

# %% [markdown]
# explode function just splits or explodes the slices

# %% [markdown]
# ##### 1.6 Heatmap

# %% [markdown]
#  Heatmaps are the graphical representation of data where each value is represented in a matrix with different color coding. heatmaps are used to find correlations between various data columns in a dataset.

# %%
#heatmap
corr = iris.corr()
fig, ax = plt.subplots()
img = ax.imshow(corr.values,cmap = "magma_r")
# set labels
ax.set_xticks(np.arange(len(corr.columns)))
ax.set_yticks(np.arange(len(corr.columns)))
ax.set_xticklabels(corr.columns)
ax.set_yticklabels(corr.columns)
cbar = ax.figure.colorbar(img, ax=ax ,cmap='')
plt.setp(ax.get_xticklabels(), rotation=30, ha="right",
         rotation_mode="anchor")
# text annotations.
for i in range(len(corr.columns)):
    for j in range(len(corr.columns)):
        if corr.iloc[i, j]b<0:
            text = ax.text(j, i, np.around(corr.iloc[i, j], decimals=2),
                       ha="center", va="center", color="black")
        else:
            text = ax.text(j, i, np.around(corr.iloc[i, j], decimals=2),
                       ha="center", va="center", color="white")
# Out:
# <ipython-input-63-ecc49a41d2fb>:10: MatplotlibDeprecationWarning: The 'cmap' parameter to Colorbar has no effect because it is overridden by the mappable; it is deprecated since 3.3 and will be removed two minor releases later.
#   cbar = ax.figure.colorbar(img, ax=ax ,cmap='')

# %% [markdown]
# - The Sepal Width and Length are not related The Petal Width and Length are highly related
# - by observing heat map we can conclude, There is a high relation between: Sepal Length & Petal Length, Sepal Length & Petal Width, and Petal Length & Petal Width

# %% [markdown]
# ##### 1.7 Word Cloud

# %% [markdown]
#  Word Cloud or Tag Cloud is a technique that is used to visualize the tags or keywords from a string. These keywords or tags are generally a single word that can help get the context of the text. The word which occurs more in the sentence will appear to be bigger in a word cloud. Word Cloud contains each word that occurs in the corpus

# %%
from wordcloud import WordCloud, ImageColorGenerator
text_1 = '''Australiformis is a monotypic genus of acan­tho­cephalans (thorny-headed or spiny-headed parasitic worms) that infest marsupials in Australia and New Guinea. The worm's body consists of a long trunk and a proboscis armed with hooks, which it uses to pierce and hold the gut wall of its host. The only species in the genus, Australiformis semoni, resembles species in the genus Moniliformis but lacks spiral muscles in the outer wall of the proboscis receptacle. The proboscis is armed with 12 rows of 13 to 15 hooks which are used to attach themselves to the small or large intestine of the host. The female worms range from 95 to 197 mm long, virtually all of which is the trunk, and 1.75 to 3.5 mm wide. There is pronounced sexual dimorphism in this species as females are around twice the size of the males, whose trunks range from 46 to 80 mm long and are about 2 mm wide. Infestation of marsupials by A. semoni may cause debilitating inflammation of the stomach (gastritis) with granulomatous ulcers.'''
text = '''I hope you all had very goood experience in attending the workshop, thank you for being patient and learning with us, we have several job openings in data analytics and Artificial intellegance projects please do let us know if you are interested on same at cloudstrats and eShiksha, cloudstrats, eshiksha, cloudstrats, eshiksha, career is important, time is valuable even your to us, take a step in your career, we are recognised by govt of maharashtra and govt of india as well, we have our products , for more please gvists at us www,eshiksha.ai , www.cloudstrats.ai, www.quantaka.ai '''
wordcloud = WordCloud().generate(text_1)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
#it is a visual representation of the words

# %% [markdown]
# ## <span style = 'color:blue'> 2.seaborn as sns generally </span>
#
# ![seaborn.png](attachment:seaborn.png)

# %% [markdown]
# Seaborn is a dataset-oriented library for making statistical representations in python. It is devoloped atop matplotlib and to create diffrent visualization.

# %% [markdown]
# ##### 2.1 simple lineplot using seaborn

# %% [markdown]
# - simple line plots using seaborn
# - The line plot is one of the most basic plot in seaborn library.
# - This plot is mainly used to visualize the data in form of some time series, i.e. in continuous manner

# %% [markdown]
# ##### 2.2 bar plot

# %%
#considering data of three diffrent penguins species for our analysis
penguins = sns.load_dataset("penguins")#loading the built-in dataset
sns.histplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %% [markdown]
# - from the above plot we can clearly observe that the distrubution of aledie is greater continued by the chinstrap and gentoo
# - distubution of the chinstrap species is not aevenly distrubuted as other species

# %% [markdown]
# ##### 2.3 scatter plot

# %% [markdown]
# - Different levels of correlation between the data points are useful to understand the relationship within the data.
#
# - The data points lying outside the given set of data can be easily identified to find the outliers.
#
# - Grouping of data points in a scatter plot can be identified as different clusters within the data

# %%
# One piece of information missing in the plots above is what species each plant is
# We'll use seaborn's FacetGrid to color the scatterplot by species
sns.FacetGrid(iris, hue="Species", size=5) \
   .map(plt.scatter, "SepalLengthCm", "SepalWidthCm") \
   .add_legend()
# with diffrent identification for diffrent species its easier for having insights of all the species
# from the plot we can see that iris setosa's sepal width is greater than both the species
# from the plot sepal length of iris verginica is greater than both the species
# Out:
# C:\Users\shyam\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# - from above plot we can clearly make out the diffrence between the sepal width and sepal length by using diffrent colours for     diffrent flowers
# - sepal width of setosa is more but the sepal length of verginica is more and versicular partially

# %% [markdown]
# ##### 2.3 A box plot or box-and-whisker plot .

# %% [markdown]
# 1. A box plot or box-and-whisker plot shows the distribution of data in a way that facilitates comparisons between variables or across levels of a categorical variable.
# 2. The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.

# %%
# We can look at an individual feature in Seaborn through a boxplot
sns.boxplot(x="Species", y="PetalLengthCm", data=iris)
# by observing the box plot we can clearly diffrentiate the  flower species with their petal and sepal dimensions respectively
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalLengthCm'>

# %% [markdown]
# - from the above plot we can clearly  observe that the petel length of iris setosa is low compared to other two species
# - petal length of iris versiculor and iris virginica is overlapping

# %%
ax = sns.boxplot(x="Species", y="PetalLengthCm", data=iris)
ax = sns.stripplot(x="Species", y="PetalLengthCm", data=iris, jitter=True, edgecolor="gray")
#Further, we see that the box plots describe that the setosa usually has smaller features with few outliers.
#The Versicolor species has average features. The virginica species has the longest features widths and lengths as compared to others.
# We'll use jitter=True so that all the points don't fall in single vertical lines

# %% [markdown]
# - from the above plot we can see the data distrubition among themselves
# - distrubution of data in iris setosa is diffrent compared to other two species

# %% [markdown]
# ##### 2.4 violin plot

# %% [markdown]
# - A violin plot depicts distributions of numeric data for one or more groups using density curves.
# - On each side of the line is a kernel density estimation to show the distribution shape of the data. Wider sections of the violin plot represent a higher probability that members of the population will take on the given value; the skinnier sections represent a lower probability.
# - The violinplot shows density of the length and width in the species. The thinner part denotes that there is less density         whereas the fatter part conveys higher density

# %%
# A violin plot combines the benefits of the previous two plots and simplifies them
# Denser regions of the data are fatter, and sparser thiner in a violin plot
sns.violinplot(x="Species", y="PetalLengthCm", data=iris, size=6)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalLengthCm'>

# %% [markdown]
#  - Thinner part denotes that there is less density, whereas the fatter part conveys higher density
#  - from the plot We can see the probability density of the various features.
#  - we can have clear picture than the sensity of the iris setosa is diffrent from both the species.

# %% [markdown]
# ##### 2.5 Facetgrid

# %% [markdown]
# 1. This class maps a dataset onto multiple axes arrayed in a grid of rows and columns that correspond to levels of variables in the dataset. The plots it produces are often called “lattice”, “trellis”, or “small-multiple” graphics.
# 2. It can also represent levels of a third variable with the hue parameter, which plots different subsets of data in different colors
# 3. creates and visualizes a kernel density estimate of the underlying feature

# %%
sns.FacetGrid(iris, hue="Species", size=6) \
   .map(sns.kdeplot, "PetalLengthCm") \
   .add_legend()
# from the plot we can easily make out that, setosa is easily separable while some portions of Versicolor and virginica are mixed.

# %% [markdown]
# - from the above plot we can clearly make a statement that data distrubution of iris setosa petal length is not overlapping with any other species of iris
# - Iris versicolor's petal length is overlapping with the iris virginica

# %% [markdown]
# ##### 2.6 Pairplot

# %% [markdown]
# 1. Pairplot visualizes given data to find the relationship between them where the variables can be continuous or categorical.
# 2. Pairplot function will create a grid of Axes such that each numeric variable in data will by shared across the y-axes across a single row and the x-axes across a single column
# 3. pairplot shows the bivariate relation between each pair of features

# %%
# The diagonal elements in a pairplot show the histogram by default
# We can update these elements to show other things, such as a kde
sns.pairplot(iris.drop("Id", axis=1), hue="Species", size=3, diag_kind="kde")
# Out:
# C:\Users\shyam\anaconda3\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# - pairplot always tries to plot the grid of scatter plots by considering all the variables and histogram by default diagonally
# - in above plot we can clearly observe that every single variable is considered for comparing it with each other

# %% [markdown]
# ## <span style = 'color:blue'> andrew curves</span>.
# ###### Andrews curves are a method for visualizing multidimensional data by mapping each observation onto a function with mean, distances and variences. We will be getting into andrew curves in future when we are dealing with advanced machine learning algorithms.

# %% [markdown]
# 1. Named after statistician david F Andrew
# 2. Andrews Curves are created by defining a finite Fourier Series which is an equation of sine curves.
# 3. Andrews curves are used for visualizing high-dimensional data by mapping each observation onto a function. It preserves means, distance, and variances.

# %%
from pandas.plotting import andrews_curves
andrews_curves(iris.drop("Id", axis=1), "Species")
# Out:
# <AxesSubplot:>

# %%
# connecting the features for each data sample
from pandas.plotting import parallel_coordinates
parallel_coordinates(iris.drop("Id", axis=1), "Species")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Another multivariate visualization technique pandas has is radviz Which puts each feature as a point on a 2D plane, and then simulates having each sample attached to those points through a spring weighted, by the relative value for that feature

# %%
from pandas.plotting import radviz
radviz(iris.drop("Id", axis=1), "Species")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Example for andrew curve

# %%
# importing various package
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# making data frame from csv file
df = pd.read_csv(
    'https://raw.github.com/pandas-dev/'
    'pandas/master/pandas/tests/io/data/csv/iris.csv'
)

# Creating Andrews curves
x = pd.plotting.andrews_curves(df, 'Name')

# ploting the Curve
x.plot()

# Display
plt.show()

# %% [markdown]
# # Thank you

# %%
def add():
    a = int(input())
    b = int(input())
    print("sum of",a+b)

# %%
add()
# Out:
# 23
# 45
# sum of 68

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-62aa4fb7-2325-45ae-9e74-d497295417f9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-62aa4fb7-2325-45ae-9e74-d497295417f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
add()
# Out:
# 12
# 45
# sum of 57
